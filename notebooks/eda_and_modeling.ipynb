# %% [markdown]
# # LendingClub Credit Risk — EDA & Modeling
#
# Scratch notebook for data exploration, feature engineering iteration, and model comparison.
# Finalized logic gets moved into `model/preprocess.py` and `model/train.py`.

# %%
import pandas as pd
import numpy as np

RAW_PATH = "../data/raw/"
PROCESSED_PATH = "../data/processed/"

# %% [markdown]
# ## 1. Load raw data (FR-1)

# %%
# df = pd.read_csv(RAW_PATH + "<dataset_filename>.csv", low_memory=False)
# df.shape, df.dtypes

# %% [markdown]
# ## 2. Filter to resolved loans + binarize target (FR-2, FR-3)

# %% [markdown]
# ## 3. Missing value handling (FR-4)

# %% [markdown]
# ## 4. Feature engineering (FR-5)

# %% [markdown]
# ## 5. Categorical encoding (FR-6)

# %% [markdown]
# ## 6. Train/test split + imbalance handling (FR-9)

# %% [markdown]
# ## 7. Baseline: Logistic Regression (FR-7)

# %% [markdown]
# ## 8. Primary model: LightGBM (FR-8)

# %% [markdown]
# ## 9. Evaluation: AUC-ROC, Precision, Recall, F1 (FR-10)

# %% [markdown]
# ## 10. SHAP explainability (FR-11)

# %% [markdown]
# ## 11. Persist model artifact (FR-12)
